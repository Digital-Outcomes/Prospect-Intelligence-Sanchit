# %%
import os,random,sys,time
from urllib.parse import urlparse
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
browser = webdriver.Chrome()

# %%
browser.get('https://www.linkedin.com/uas/login')
file = open('config.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]

field = browser.find_element_by_id('username')
field.send_keys(username)

field = browser.find_element_by_id('password')
field.send_keys(password)

field.submit()

# %%
profileLink = 'https://www.linkedin.com/in/vaibhavg/'
browser.get(profileLink)

# %%
SCROLL_PAUSE_TIME = 5

last_height = browser.execute_script('return document.body.scrollHeight')

for i in range(5) :
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight/4)")
    time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
# time.sleep(30)
src = browser.page_source
soup = BeautifulSoup(src)
src = browser.page_source
soup = BeautifulSoup(src)
src = browser.page_source
soup = BeautifulSoup(src)

# %%
soup
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en"><head>
# <script async="" src="https://platform.linkedin.com/js/analytics.js"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>(11) Vaibhav Goyal | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static-exp1.licdn.com/sc/h/3no7sonr5rirnososqttxazy5" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="false" name="is-http2"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#0077B5" name="theme-color"/>
# ...

# %%
name_div = soup.find('h1',{'class' : 'text-heading-xlarge'})
print(name_div)
# Out:
# <h1 class="text-heading-xlarge inline t-24 v-align-middle break-words">Vaibhav Goyal</h1>

# %%
name_loc = name_div.get_text()
name = name_loc

# %%
connections_div = soup.find('span' , {'class' : 't-bold'})
connections = connections_div.get_text()
print(connections_div.get_text())
# Out:
# 3,871

# %%
browser.find_element_by_class_name("inline-show-more-text__button--light").click()
src = browser.page_source
soup = BeautifulSoup(src)
about_div = soup.find_all('div', {'class' : 'mt4'})
# currentCompany = about_div[0].get_text()
about = about_div[0].get_text()
print(about)
# Out:
#     I am a serial entrepreneur with experience in building and operating digital businesses/products across media & entertainment, e-commerce, social media, health and wellness, human resources and recruitment, fashion & lifestyle, deep tech, marketing tech & omnichannel retail I love working with high growth organizations, creating sustainable business models for digital businesses, building digital products, platforms and AI/ML based models & executing growth hacking techniques I have led and have been an integral part of digital transformations of industries and companies1. Pioneer of OTT industry growth in India2. Build up of Jio's digital revolution in India and core part of Jio media services3. Integral part of Shemaroo's digital transformation journey4. Build up of Deeptech revolution in India5. Revamped an edtech business in govt exams test preparation space6. Transforming a physical health & wellness brand digitallyI am a mentor at Nasscom's DeepTech club and happy to assist
# ...

# %%
# exp_section = soup.find('section', attrs = {'id': 'experience-section'})
# exp_section = exp_section.find('ul')
# div_tag = exp_section.find_all('div')
# print(div_tag[1])
exp_section = soup.find_all('li', attrs = {'class' : 'pv-entity__position-group-pager'})
experience = []
for exp in exp_section :
    try :
        experience.append(exp.find('p' , attrs = {'class' : 'pv-entity__secondary-title'}).get_text())
    except :
        print("Couldnt Parse")
print(exp_section)
# Out:
# [<li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember269"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1613797789"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/company/digitaloutcomes/" id="ember271"> <div class="pv-entity__logo company-logo">
# <img alt="digital outcomes " class="pv-entity__logo-img EntityPhoto-square-5 lazy-image ember-view" id="ember273" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C4D0BAQGS3FI9Pr_77Q/company-logo_100_100/0/1622077751921?e=1633564800&amp;v=beta&amp;t=M5ItGOssv3XDFh9J5oHv1JwYRLjoqDTHNcugOtm05lE"/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section mb2">
# <h3 class="t-16 t-black t-bold">Co-Founder</h3>
# ...

# %%
edu_section = soup.find_all('li', attrs = {'class' : 'pv-education-entity'})
education = []
for edu in edu_section :
    education.append(edu.find('h3' , attrs = {'class' : 'pv-entity__school-name'}).get_text())
print(education)
# Out:
# ['Indian Institute of Technology, Madras', 'S.P. Jain Institute of Management & Research', 'Modern Senior Secondary School']

# %%
profile = {"name" : name , "connections":connections , "about" : about , "experience" : experience , "education" : education}

# %%
for pro in profile :
    print(pro + " " + str(profile[pro]))
# Out:
# name Vaibhav Goyal
# connections 3,871
# about
#
# ...

# %%
# time.sleep(10)
browser.execute_script("window.scrollTo(0,0)")
time.sleep(5)

browser.find_element_by_class_name("link-without-visited-state").click()
# soup.find('a',attrs = {'class' : 'link-without-visited-state'})
# print(a)

# %%
time.sleep(5)
src = browser.page_source
soup = BeautifulSoup(src)

# %%
contact_info = soup.find_all('a', attrs = {'class' : 'pv-contact-info__contact-link'})
contact = []
for i in contact_info :
    contact.append(i.get_text())
print(contact)
# Out:
# ['\n        linkedin.com/in/vaibhavg\n      ', '\n  digitaloutcomes.io\xa0\n', '\n          vaibhav@digitaloutcomes.io\n        ']

# %%
try :
    phone_number = soup.find_all('li',attrs ={'class':'pv-contact-info__ci-container'})
    phone_number = phone_number[1].find('span',attrs={'class' : 't-14'})
    phone_number = phone_number.get_text()
    print(phone_number)
except :
    phone_number = "No Phone Number"
    print("No Phone number")
# Out:
#                 +91 9920565089

# %%
browser.get(profileLink)
SCROLL_PAUSE_TIME = 5

last_height = browser.execute_script('return document.body.scrollHeight')

for i in range(5) :
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight/4)")
    time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
    
src = browser.page_source
soup = BeautifulSoup(src)

# %%
browser.find_element_by_class_name("pv-profile-section__card-action-bar").click()
time.sleep(5)

# %%
# browser.find_element_by_class_name("pv-recent-activity-detail__pill").click()

# %%
l=browser.find_elements_by_class_name("pv-recent-activity-detail__pill")
l[2].click()
time.sleep(5)
SCROLL_PAUSE_TIME = 5

last_height = browser.execute_script('return document.body.scrollHeight')

for i in range(20) :
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight/2)")
    time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
browser.execute_script("window.scrollTo(0,0)")

l=browser.find_elements_by_class_name("see-more")
for i in range(len(l)) :
    l[i].click()
time.sleep(5)
SCROLL_PAUSE_TIME = 5

last_height = browser.execute_script('return document.body.scrollHeight')

for i in range(20) :
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight/2)")
    time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src)

# %%
posts = []
for i in range(len(l)) :
    try :
        post_info = soup.find_all('span', attrs = {'class' : 'break-words'})
#     print(post_info[0].find('span').find('span').get_text())
        posts.append(post_info[i].find('span').find('span').get_text())
    except :
        print("waited")
print(posts)
# Out:
# waited
# waited
# ...

# %%
likes = []
like_info = soup.find_all('button' , attrs = {'class':'social-details-social-counts__count-value'})
for i in range(len(like_info)) :
    likes.append(like_info[i].find('span').get_text())
print(likes)
# Out:
# ['4', '\n              1 comment\n            ', '6', '\n              1 comment\n            ', '7', '3', '3', '8', '11', '10']

# %%
profile['contact'] = contact 
profile['phone_number'] = phone_number
profile['posts'] = posts
profile['likes_comments'] = likes 
for pro in profile :
    print(pro + " " + str(profile[pro]))
# Out:
# name Vaibhav Goyal
# connections 3,871
# about
#
# ...

# %%
import json


with open('Ankur.txt', 'w') as file:
     file.write(json.dumps(profile)) # use `json.loads` to do the reverse
