# %%
import os,random,sys,time
from urllib.parse import urlparse
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
browser = webdriver.Chrome()

# %%
browser.get('https://www.linkedin.com/uas/login')
file = open('config.txt')
lines = file.readlines()
username = lines[0]
password = lines[1]

field = browser.find_element_by_id('username')
field.send_keys(username)

field = browser.find_element_by_id('password')
field.send_keys(password)

field.submit()

# %%
profileLink = 'https://www.linkedin.com/in/sanchit-gupta-361581189/'
browser.get(profileLink)

# %%
SCROLL_PAUSE_TIME = 5

last_height = browser.execute_script('return document.body.scrollHeight')

for i in range(5) :
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight/4)")
    time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
# time.sleep(30)
src = browser.page_source
soup = BeautifulSoup(src)
src = browser.page_source
soup = BeautifulSoup(src)
src = browser.page_source
soup = BeautifulSoup(src)

# %%
soup
# Out:
# <html class="theme theme--mercado artdeco windows" lang="en"><head>
# <script async="" src="https://platform.linkedin.com/js/analytics.js"></script><script type="application/javascript">!function(i,n){void 0!==i.addEventListener&&void 0!==i.hidden&&(n.liVisibilityChangeListener=function(){i.hidden&&(n.liHasWindowHidden=!0)},i.addEventListener("visibilitychange",n.liVisibilityChangeListener))}(document,window);</script>
# <title>Sanchit Gupta | LinkedIn</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta class="mercado-icons-sprite" content="https://static-exp1.licdn.com/sc/h/3no7sonr5rirnososqttxazy5" id="artdeco-icons/static/images/sprite-asset" name="asset-url"/>
# <meta content="" name="description"/>
# <meta content="notranslate" name="google"/>
# <meta content="false" name="is-http2"/>
# <meta content="voyager-web" name="service"/>
# <meta content="#0077B5" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <link href="/voyager/manifest.json" rel="manifest"/>
# <link href="https://static-exp1.licdn.com/sc/h/2yn5wo11kffdnhiphh4iw1znj" id="ui-theme" rel="stylesheet"/>
# <link disabled="" href="https://static-exp1.licdn.com/sc/h/4qgmjwutc65z38oy6qqd4wv9v" id="ui-theme-dark" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/5taahw99n0xqtbq9e6orrbb5g" rel="stylesheet"/>
# <meta content="%7B%22modulePrefix%22%3A%22extended%22%2C%22environment%22%3A%22production%22%2C%22aide%22%3A%7B%22isIsolatedBuild%22%3Afalse%7D%2C%22client-sensor-web%22%3A%7B%22mpName%22%3A%22voyager-web%22%7D%2C%22ember-media-player%22%3A%7B%22lazyLoad%22%3Atrue%7D%2C%22ember-fetch%22%3A%7B%22preferNative%22%3Atrue%7D%2C%22image-editor%22%3A%7B%22lazyLoad%22%3Atrue%7D%2C%22rootURL%22%3A%22%2F%22%2C%22routerRootURL%22%3A%22%2F%22%2C%22deviceFormFactor%22%3A%22DESKTOP%22%2C%22locationType%22%3A%22voyager-location%22%2C%22namespace%22%3A%22voyager%2Fapi%22%2C%22EmberENV%22%3A%7B%22FEATURES%22%3A%7B%7D%2C%22_APPLICATION_TEMPLATE_WRAPPER%22%3Afalse%2C%22_DEFAULT_ASYNC_OBSERVERS%22%3Atrue%2C%22_JQUERY_INTEGRATION%22%3Afalse%2C%22_TEMPLATE_ONLY_GLIMMER_COMPONENTS%22%3Atrue%7D%2C%22APP%22%3A%7B%22locale%22%3A%22en_US%22%2C%22rumConfig%22%3A%7B%22pageKeyPrefix%22%3A%22d_%22%2C%22beacon-service%22%3A%22tracking%22%2C%22beacon-url%22%3A%22%2Fli%2Ftrack%22%2C%22event-name%22%3A%22RealUserMonitoringEvent%22%2C%22enable-cdn-tracking%22%3Atrue%2C%22enable-pop-tracking%22%3Atrue%2C%22user-timing-mark-enabled%22%3Atrue%2C%22web-vitals-enabled%22%3Atrue%7D%2C%22name%22%3A%22extended%22%2C%22version%22%3A%220.0.0-productspec%2B5f34e34c%22%7D%2C%22contentSecurityPolicy%22%3A%7B%22default-src%22%3A%22%5C%22none%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22script-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.linkedin.com%22%2C%22font-src%22%3A%22%5C%22self%5C%22%20*.licdn.com%20*.licdn-ei.com%20*.slidesharecdn.com%22%2C%22frame-src%22%3A%22*.youtube.com%20*.youtube-nocookie.com%20*.slideshare.net%22%2C%22connect-src%22%3A%22%5C%22self%5C%22%20localhost%3A*%20*.linkedin.com%22%2C%22img-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%20spdy.linkedin.com%20spdy.linkedin-ei.com%20*.youtube.com%20*.youtube-nocookie.com%22%2C%22style-src%22%3A%22%5C%22self%5C%22%20%5C%22unsafe-inline%5C%22%20*.licdn.com%20*.licdn-ei.com%22%2C%22media-src%22%3A%22%5C%22self%5C%22%20*.slidesharecdn.com%20*.licdn.com%20*.licdn-ei.com%22%7D%2C%22tracking%22%3A%7B%22validation%22%3A%7B%22throwOnError%22%3Atrue%7D%2C%22appId%22%3A%22com.linkedin.flagship3.d_web%22%2C%22pageKeyPrefix%22%3A%22d_%22%2C%22pveTrackingInfo%22%3A%7B%22osName%22%3A%22phone_web%22%7D%2C%22impression%22%3A%7B%22timeThreshold%22%3A300%2C%22percentageThreshold%22%3A50%2C%22viewportOffset%22%3A%7B%22top%22%3A52%2C%22bottom%22%3A0%2C%22left%22%3A0%2C%22right%22%3A0%7D%7D%2C%22comScore%22%3A%7B%22enabled%22%3Afalse%7D%2C%22externalTracking%22%3A%7B%22enabled%22%3Atrue%7D%2C%22retryConfig%22%3A%7B%22inMemory%22%3A%7B%22attemptLimit%22%3A4%2C%22statusCodes%22%3A%5B502%2C504%5D%7D%2C%22persist%22%3A%7B%22attemptLimit%22%3A3%2C%22statusCodes%22%3A%5B429%2C503%5D%2C%22maxNumber%22%3A1000%2C%22batchEvictionNumber%22%3A300%2C%22throttleWait%22%3A300000%7D%7D%7D%2C%22enableComponentUsageReport%22%3Afalse%2C%22i18n%22%3A%7B%22cldrRelaxedModeEnabled%22%3Atrue%7D%2C%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets%2Fimg%2Forganization%2Ffacepile%2FMan_08.png%22%2C%22assets%2Fimg%2Forganization%2Ffacepile%2FMan_11.png%22%2C%22assets%2Fimg%2Forganization%2Ffacepile%2FWoman_17.png%22%2C%22assets%2Fimg%2Fchina-icp-filing.png%22%2C%22assets%2Fimg%2Forganization%2Fdesktop-screenshot.png%22%2C%22assets%2Fimg%2Forganization%2Fmobile-screenshot.png%22%2C%22assets%2Fimg%2Fprofile%2Fdesktop-photo-upload-add-photo.png%22%2C%22assets%2Fhighcharts%2Fhighcharts.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Fmap.js%22%2C%22assets%2Fhighcharts%2Fmodules%2Faccessibility.js%22%2C%22assets%2FcloudSDK%2FOneDriveSDK.js%22%2C%22assets%2FcloudSDK%2FDropboxSDK.js%22%2C%22assets%2Fproj4.js%22%2C%22assets%2Fspectroscopy-worker.js%22%2C%22assets%2Fworld.js%22%2C%22assets%2Fsrc%2Fchartbeat.js%22%2C%22assets%2Fpowerpoint-coach%2FCoachPackage.js%22%2C%22assets%2Ffavicon.ico%22%2C%22assets%2Ffavicon-notification.ico%22%2C%22assets%2Fimg%2Fhiring%2Fclose-job%2F ...
# <!-- EMBER_CLI_FASTBOOT_TITLE --><!-- EMBER_CLI_FASTBOOT_HEAD -->
# <link href="https://static-exp1.licdn.com/sc/h/al2o9zrvru7aqj8e1x2rzsrca" id="favicon-ico" rel="shortcut icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed"/>
# <link href="https://static-exp1.licdn.com/sc/h/2if24wp7oqlodqdlgei1n1520" rel="apple-touch-icon-precomposed" sizes="57x57"/>
# <link href="https://static-exp1.licdn.com/sc/h/eahiplrwoq61f4uan012ia17i" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# <link href="https://static-exp1.licdn.com/sc/h/5v9kk41iyzwa7a8fsivxrtw3r" rel="stylesheet"/>
# <link href="https://static-exp1.licdn.com/sc/h/38w2q368tbgasyg8mmyc2vpwg" rel="stylesheet"/>
# <meta content='{"assets/img/organization/facepile/Man_08.png":"https://static-exp1.licdn.com/sc/h/3o5hiooua9mbbubbzedvypuug","assets/img/organization/facepile/Man_11.png":"https://static-exp1.licdn.com/sc/h/8gm9tyw8v6dpf8h885mp8v3oz","assets/img/organization/facepile/Woman_17.png":"https://static-exp1.licdn.com/sc/h/cxwbr3jqacyw9dme6x58vm9j4","assets/img/china-icp-filing.png":"https://static-exp1.licdn.com/sc/h/cbn91jpp9vuid7olk3y6qmbpj","assets/img/organization/desktop-screenshot.png":"https://static-exp1.licdn.com/sc/h/ev2ewp91pnvtl0gcyt4xht0b5","assets/img/organization/mobile-screenshot.png":"https://static-exp1.licdn.com/sc/h/3v3wzhnr3kapuzwpk1zt6r1jt","assets/img/profile/desktop-photo-upload-add-photo.png":"https://static-exp1.licdn.com/sc/h/c5ybm82ti04zuasz2a0ubx7bu","assets/highcharts/highcharts.js":"https://static-exp1.licdn.com/sc/h/7vc1yxvrhoaqvxvgdcx84izud","assets/highcharts/modules/map.js":"https://static-exp1.licdn.com/sc/h/gi83hdcgsuslhhy94s6p600i","assets/highcharts/modules/accessibility.js":"https://static-exp1.licdn.com/sc/h/5xoe59r4uc5k5i40sulrwj9c3","assets/cloudSDK/OneDriveSDK.js":"https://static-exp1.licdn.com/sc/h/y41qzg45cwdddxb07wfr97dx","assets/cloudSDK/DropboxSDK.js":"https://static-exp1.licdn.com/sc/h/cjxfqe7mtoe4m7iatjlvralxs","assets/proj4.js":"https://static-exp1.licdn.com/sc/h/3kxybliwk7osbe9qc8d6bnza2","assets/spectroscopy-worker.js":"https://static-exp1.licdn.com/sc/h
{"trackingInfo":null,"treatment":"control","testKey":"voyager.web.nav.job-posting-jobs-led-entry-points","primaryEvaluationUrn":null},"voyager.iac.web.import-communities":{"trackingInfo":null,"treatment":"control","testKey":"voyager.iac.web.import-communities","primaryEvaluationUrn":null},"voyager.web.careers-search-dash-hits-migration":{"trackingInfo":null,"treatment":"control","testKey":"voyager.web.careers-search-dash-hits-migration","primaryEvaluationUrn":null},"voyager.web.infraux-mercado-theme":{"trackingInfo":null,"treatment":"enabled","testKey":"voyager.web.infraux-mercado-theme","primaryEvaluationUrn":null},"voyager.web.messaging-enable-unread-badger-onboarding":{"trackingInfo":{"experimentId":4142136,"segmentIndex":4,"treatmentIndex":1,"urn":"urn:li:member:744922297","trackingUrns":null},"treatment":"enabled","testKey":"voyager.web.messaging-enable-unread-badger-onboarding","primaryEvaluationUrn":null},"voyager.web.organization-product-remove-review":{"trackingInfo":null,"treatment":"control","testKey":"voyager.web.organization-product-remove-review","primaryEvaluationUrn":null},"voyager.web.search-home-graphql-endpoint":{"trackingInfo":null,"treatment":"control","testKey":"voyager.web.search-home-graphql-endpoint","primaryEvaluationUrn":null},"voyager.web.onboarding-use-dash-goals":{"trackingInfo":null,"treatment":"enabled","testKey":"voyager.web.onboarding-use-dash-goals","primaryEvaluationUrn":null},"voyager.web.messaging-video-conference-duration":{"trackingInfo":{"experimentId":4342194,"segmentIndex":2,"treatmentIndex":0,"urn":"urn:li:member:744922297","trackingUrns":null},"treatment":"control","testKey":"voyager.web.messaging-video-conference-duration","primaryEvaluationUrn":null},"voyager.web.smp-review-invitation":{"trackingInfo":null,"treatment":"control","testKey":"voyager.web.smp-review-invitation","primaryEvaluationUrn":null},"voyager.web.profile-guided-edit-position":{"trackingInfo":{"experimentId":4353551,"segmentIndex":2,"treatmentIndex":1,"urn":"urn:li:member:744922297","trackingUrns":null},"treatment":"enabled","testKey":"voyager.web.profile-guided-edit-position","primaryEvaluationUrn":null},"voyager.web.premium-cancel-winback-promotions-pem-tracking":{"trackingInfo":null,"treatment":"control","testKey":"voyager.web.premium-cancel-winback-promotions-pem-tracking","primaryEvaluationUrn":null},"voyager.web.claim-jobs-banner-on-company-page":{"trackingInfo":{"experimentId":4352848,"segmentIndex":1,"treatmentIndex":1,"urn":"urn:li:member:744922297","trackingUrns":null},"treatment":"enabled","testKey":"voyager.web.claim-jobs-banner-on-company-page","primaryEvaluationUrn":null},"pemberly.tracking.flush-rum-on-hidden":{"trackingInfo":{"experimentId":4325213,"segmentIndex":1,"treatmentIndex":0,"urn":"urn:li:member:744922297","trackingUrns":null},"treatment":"control","testKey":"pemberly.tracking.flush-rum-on-hidden","primaryEvaluationUrn":null},"voyager.web.video-native-loader-octaned":{"trackingInfo":null,"treatment":"enabled","testKey":"voyager.web.video-native-loader-octaned","primaryEvaluationUrn":null},"voyager.web.profile-guided-edit-past-position":{"trackingInfo":{"experimentId":4353529,"segmentIndex":2,"treatmentIndex":0,"urn":"urn:li:member:744922297","trackingUrns":null},"treatment":"control","testKey":"voyager.web.profile-guided-edit-past-position","primaryEvaluationUrn":null},"voyager.web.onboarding-pymk-typeahead-v2":{"trackingInfo":null,"treatment":"contro ...
# <meta content="false" name="isGuest"/>
# <meta data-mode="BIGPIPE" name="renderingMode"/>
# <!--%SSR_HEAD*[]%-->
# <meta content="enabled" name="Fastlane"/>
# <meta content="12000" name="bigpipeResponseTimeout"/>
# <meta content="false" name="bigpipeJetRethrowError"/>
# <meta content='["static\\.licdn\\.com","media\\.licdn\\.com","voyager/api/typeahead/hits"]' name="bigpipeBlacklistUrls"/>
# <meta content="true" name="isQueryTunnelRequestSupported"/>
# <script src="https://static-exp1.licdn.com/sc/h/9lm1w74nbjr3k3lavicf1gdym"></script>
# <meta content="%7B%7D" name="abi/config/environment"/>
# <meta content="%7B%7D" name="article-reader/config/environment"/>
# <meta content="%7B%7D" name="career-services/config/environment"/>
# <meta content="%7B%7D" name="company-creation/config/environment"/>
# <meta content="%7B%22sparkPlaceholders%22%3A%7B%22includeHashes%22%3A%5B%22assets/media-player.amd.js%22%5D%7D%7D" name
://static-exp1.licdn.com/sc/h/28wqz26ega3mwks2p8y7owqan"></script><script src="https://static-exp1.licdn.com/sc/h/b0gtfkfjt2v15024668fdc3lq"></script><script src="https://static-exp1.licdn.com/sc/h/4sjentcp6hzykkhjmd6zfh66"></script><script src="https://static-exp1.licdn.com/sc/h/28wqz26ega3mwks2p8y7owqan"></script>
# <script crossorigin="" data-fastboot-src="assets/extended.js" src="https://static-exp1.licdn.com/sc/h/7xktgrrf5xx98018r437crrwg"></script>
# <div id="artdeco-modal-outlet"></div>
# <code id="bpr-guid-2672448" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:nZx6/1e1AAbOHh075gv083zrunZT186/K+rx5FP70A4=","elements":[{"lixTracking":{"urn":"urn:li:member:744922297","segmentIndex":3,"experimentId":3295843,"treatmentIndex":0,"$type":"com.linkedin.voyager.common.ChameleonConfigLixTrackingInfo"},"data":{"namespace":"dddd","locale":"en_US","message":"new original","key":"312312dd","$type":"com.linkedin.voyager.common.ChameleonConfigDataI18n"},"displayName":"Admin: test for messaging seg","description":"dasdas","lixTreatment":"control","lixKey":"chameleon.MESSAGING:en.copy.8773","creatorDisplayName":"plin","status":"INITIAL_RAMP","$type":"com.linkedin.voyager.common.ChameleonConfigItem"},{"lixTracking":{"urn":"urn:li:member:744922297","segmentIndex":3,"experimentId":4325055,"treatmentIndex":0,"$type":"com.linkedin.voyager.common.ChameleonConfigLixTrackingInfo"},"data":{"namespace":"premium/templates/components/chooser/plan-card","locale":"en_US","message":"Select plan","key":"i18n_card_select_plan","$type":"com.linkedin.voyager.common.ChameleonConfigDataI18n"},"displayName":"card_select_plan","description":"testing 'Learn more' on SKU cards, vs control of 'Select plan' ","lixTreatment":"control","lixKey":"chameleon.PREMIUM:us.copy.17654","creatorDisplayName":"cyount","status":"MAX_RAMP","$type":"com.linkedin.voyager.common.ChameleonConfigItem"},{"lixTracking":{"urn":"urn:li:member:744922297","segmentIndex":3,"experimentId":3344128,"treatmentIndex":1,"$type":"com.linkedin.voyager.common.ChameleonConfigLixTrackingInfo"},"data":{"namespace":"sharing-v2/templates/share-box-v2","locale":"en_US","message":"Share that you‘re hiring","key":"i18n_share_job_btn_v2","$type":"com.linkedin.voyager.common.ChameleonConfigDataI18n"},"displayName":"sharebox_jobs_cta","description":"See if making consistent CTAs for share + profile will up or reduce engagement with Online Jobs.","lixTreatment":"VAR_8340_t3493_PR","lixKey":"chameleon.OJ:hijp.copy.8339","creatorDisplayName":"michli","status":"PERMANENT_RAMP","$type":"com.linkedin.voyager.common.ChameleonConfigItem"},{"lixTracking":{"urn":"urn:li:member:744922297","segmentIndex":3,"experimentId":3417563,"treatmentIndex":1,"$type":"com.linkedin.voyager.common.ChameleonConfigLixTrackingInfo"},"data":{"namespace":"organization-base/templates/components/top-card/secondary-content","locale":"en_US","message":"Chat with&amp;nbsp;{:connection,name} {:count,choice,0#works|1#&amp; {:count,number,integer} other {:count,choice,singular#connection|plural#connections} who work} here \n","key":"i18n_org_connections_work_here","$type":"com.linkedin.voyager.common.ChameleonConfigDataI18n"},"displayName":"CompanyPage_MessageCTA","description":"Adding \"Message\" and alternative copy variations on Company Page where we show mutual connections. Assessing whether using active copy that reflects the next best action drives lifts in unique message senders and messages sent.","lixTreatment":"VAR_8968_t3763_PR","lixKey":"chameleon.MESSAGING:en.copy.8966","creatorDisplayName":"crowshan","status":"MAX_RAMP","$type":"com.linkedin.voyager.common.ChameleonConfigItem"},{"lixTracking":{"urn":"urn:li:member:744922297","segmentIndex":2,"experimentId":3094445,"treatmentIndex":1,"$type":"com.linkedin.voyager.common.ChameleonConfigLixTrackingInfo"},"data":{"namespace":"global-nav/templates/components/global-nav-me","locale":"en_US","message":"My Posted Jobs","key":"i18n_job_posting_account","$type":"com.linkedin.voyager.common.ChameleonConfigDataI18n"},"displayName":"job_posting_account","description":"Entry point test on Me drop down.","lixTreatment":"VAR_7182_t3000_PR","lixKey":"chameleon.OJ:hijp.copy.7180","creatorDisplayName":"clinn","status":"PERMANENT_RAMP","$type":"com.linkedin.voyager.common.ChameleonConfigItem"},{"lixTracking":{"urn":"urn:li:member:744922297","segmentIndex":2,"experimentId":4155191,"treatmentIndex":1,"$type":"com.linkedin.voyager.common.ChameleonConfigLixTrackingInfo"},"data":{"namespace":"test_vd_3_1_Namespace","locale" ...
# </code>
# <code id="datalet-bpr-guid-2672448" style="display: none">
#   {"request":"/voyager/api/chameleonConfig","status":200,"body":"bpr-guid-2672448","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-2672448" src="..." style="display: none"/><code id="bpr-guid-2672449" style="display: none">
#   {"data":{"canBrowseProfiles":false,"reactivationFeaturesEligible":false,"canViewJobAnalytics":false,"canViewWVMP":false,"premiumFreeTrialEligible":true,"canAccessLearningVideos":false,"premiumLearningUpgradeEligible":false,"canViewCompanyInsights":false,"$type":"com.linkedin.voyager.premium.FeatureAccess"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-2672449" style="display: none">
#   {"request":"/voyager/api/premium/featureAccess?name\u003DreactivationFeaturesEligible","status":200,"body":"bpr-guid-2672449","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-2672449" src="..." style="display: none"/><code id="bpr-guid-2672450" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:uPYuDSPXzooiHx+zPOguG1+f+JFMWTWFEfhiIQtEFMM=","elements":[],"paging":{"count":10,"start":0,"total":0,"links":[]},"$type":"com.linkedin.restli.common.CollectionResponse"},"included":[]}
# </code>
# <code id="datalet-bpr-guid-2672450" style="display: none">
#   {"request":"/voyager/api/takeovers","status":200,"body":"bpr-guid-2672450","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-2672450" src="..." style="display: none"/><code id="bpr-guid-2672451" style="display: none">
#   {"data":{"plainId":744922297,"publicContactInfo":{"$type":"com.linkedin.voyager.identity.shared.PublicContactInfo"},"premiumSubscriber":false,"*miniProfile":"urn:li:fs_miniProfile:ACoAACxmnLkBWHVzr1Cem5z2R87rSJ5ChjrcBGE","$type":"com.linkedin.voyager.common.Me"},"included":[{"customPronoun":null,"memorialized":false,"lastName":"Gupta","standardizedPronoun":null,"occupation":"ML Intern at Digital Outcomes","objectUrn":"urn:li:member:744922297","backgroundImage":null,"picture":{"artifacts":[{"width":100,"fileIdentifyingUrlPathSegment":"100_100/0/1568110114010?e=1629936000&amp;v=beta&amp;t=TmRejdLcBsmneEI6HO6co4Zvob_A6xkwsNW8H1xuqBQ","expiresAt":1629936000000,"height":100,"$type":"com.linkedin.common.VectorArtifact"},{"width":200,"fileIdentifyingUrlPathSegment":"200_200/0/1568110114010?e=1629936000&amp;v=beta&amp;t=IThQUdRhkagnHHhf-U2_vb3NfwYkfWmAHYzqJwrbDBg","expiresAt":1629936000000,"height":200,"$type":"com.linkedin.common.VectorArtifact"},{"width":400,"fileIdentifyingUrlPathSegment":"400_400/0/1568110114010?e=1629936000&amp;v=beta&amp;t=hwIAkfH-4MT6DfsRZfEsK9doZk2krlxnbxx5NvRqrRI","expiresAt":1629936000000,"height":400,"$type":"com.linkedin.common.VectorArtifact"},{"width":800,"fileIdentifyingUrlPathSegment":"800_800/0/1568110114010?e=1629936000&amp;v=beta&amp;t=sf-E-JIxnDYBTcr82FWtTsW9-7Qb5Kn5Vs3UBUvDmTk","expiresAt":1629936000000,"height":800,"$type":"com.linkedin.common.VectorArtifact"}],"rootUrl":"https://media-exp1.licdn.com/dms/image/C5103AQHmtrgZvVPV5g/profile-displayphoto-shrink_","$type":"com.linkedin.common.VectorImage"},"$type":"com.linkedin.voyager.identity.shared.MiniProfile","firstName":"Sanchit","entityUrn":"urn:li:fs_miniProfile:ACoAACxmnLkBWHVzr1Cem5z2R87rSJ5ChjrcBGE","publicIdentifier":"sanchit-gupta-361581189","trackingId":"I8pPo5S2TruVc5P7Vx/DPw=="}]}
# </code>
# <code id="datalet-bpr-guid-2672451" style="display: none">
#   {"request":"/voyager/api/me","status":200,"body":"bpr-guid-2672451","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-2672451" src="..." style="display: none"/><code id="bpr-guid-2672452" style="display: none">
#   {"data":{"paidProducts":["SHOW_POST_A_JOB"],"hasAccessPremium":false,"*companies":["urn:li:fs_miniCompany:71311787","urn:li:fs_miniCompany:71297309"],"memberGroup":"FREE","showStaticLearning":false,"$type":"com.linkedin.voyager.common.Nav"},"included":[{"objectUrn":"urn:li:company:71311787","entityUrn":"urn:li:fs_miniCompany:71311787","name":"Upsilon_India","showcase":false,"active":true,"logo":{"artifacts":[{"width":200,"fileIdentifyingUrlPathSegment":"200_200/0/1610020040220?e=1632960000&amp;v=beta&amp;t=5zJwMRMXuqgXOB3O7bkQLBG97Q9h-JD6rcBGC3k5Ijk","expiresAt":1632960000000,"height":200,"$type":"com.linkedin.common.VectorArtifact"},{"width":100,"fileIdentifyingUrlPathSegment":"100_100/0/1610020040220?e=1632960000&amp;v=beta&amp;t=GH2_xYiEOkOLI5WQCA0OMcjjjeSQfD8VBq3j-EDD9yo","expiresAt":1632960000000,"height":100,"$type":"com.linkedin.common.VectorArtifact"},{"width":400,"fileIdentifyingUrlPathSegment":"400_400/0/1610020040220?e=1632960000&amp;v=beta&amp;t=_QmVR9acQ9riVoDIOCinvUJAAC7UWVY-AoHORsgkvc4","expiresAt":1632960000000,"height":400,"$type":"com.linkedin.common.VectorArtifact"}],"rootUrl":"https://media-exp1.licdn.com/dms/image/C4D0BAQGwVH8codVtbg/company-logo_","$type":"com.linkedin.common.VectorImage"},"universalName":"upsilon-india","dashCompanyUrn":"urn:li:fsd_company:71311787","trackingId":"NES2TCH0S0usnV3n85WHRw==","$type":"com.linkedin.voyager.entities.shared.MiniCompany"},{"objectUrn":"urn:li:company:71297309","entityUrn":"urn:li:fs_miniCompany:71297309","name":"KARMAC","showcase":false,"active":true,"logo":{"artifacts":[{"width":200,"fileIdentifyingUrlPathSegment":"200_200/0/1609822904070?e=1632960000&amp;v=beta&amp;t=Odoes9DpNXauaiPQvImZTv37XChLJQMu9mqRIUQPFmU","expiresAt":1632960000000,"height":200,"$type":"com.linkedin.common.VectorArtifact"},{"width":100,"fileIdentifyingUrlPathSegment":"100_100/0/1609822904070?e=1632960000&amp;v=beta&amp;t=TkvtyA2_H8tp6ZVA4katNupBQO8IbFgW5T1Ij5D0_Og","expiresAt":1632960000000,"height":100,"$type":"com.linkedin.common.VectorArtifact"},{"width":400,"fileIdentifyingUrlPathSegment":"400_400/0/1609822904070?e=1632960000&amp;v=beta&amp;t=WHdDyBWwncRSSH1Shyuof2ExqyKkRGsAscGJbz7lANE","expiresAt":1632960000000,"height":400,"$type":"com.linkedin.common.VectorArtifact"}],"rootUrl":"https://media-exp1.licdn.com/dms/image/C560BAQGot_QxTxY4CQ/company-logo_","$type":"com.linkedin.common.VectorImage"},"universalName":"karmacglobal","dashCompanyUrn":"urn:li:fsd_company:71297309","trackingId":"oyO5SGOsQXisPFRQuyxV8A==","$type":"com.linkedin.voyager.entities.shared.MiniCompany"}]}
# </code>
# <code id="datalet-bpr-guid-2672452" style="display: none">
#   {"request":"/voyager/api/nav","status":200,"body":"bpr-guid-2672452","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-2672452" src="..." style="display: none"/><code id="bpr-guid-2672453" style="display: none">
# ...
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card display-flex">
# <div class="msg-selectable-entity msg-selectable-entity--3">
# <div class="msg-facepile-grid msg-facepile-grid--no-facepile msg-facepile-grid--3 msg-selectable-entity__entity">
# <!-- --> <img alt="Vidushii Rathi" class="lazy-image msg-facepile-grid__img msg-facepile-grid__img--person ember-view" id="ember205" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C5603AQFE_7KaMQtUGg/profile-displayphoto-shrink_100_100/0/1613040624167?e=1629936000&amp;v=beta&amp;t=ou6DpVeqcwuYuo67rKWzSeYMm7JX0-AW2hj1GxmQRwI"/>
# </div>
# <div class="msg-selectable-entity__checkbox-container">
# <input class="ember-checkbox msg-selectable-entity__input simple-form ember-view" id="checkbox-msg-selectable-entity__checkbox-ember204" tabindex="-1" type="checkbox"/>
# <label aria-label="Select conversation" class="msg-selectable-entity__checkbox-label ml2" for="checkbox-msg-selectable-entity__checkbox-ember204">
# </label>
# <div class="msg-selectable-entity__checkbox-circle-container">
# <div class="msg-selectable-entity__checkbox-circle">
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden pl2">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Vidushii Rathi
#                       </h4>
# <time class="msg-overlay-list-bubble-item__time-stamp t-12 t-normal t-black--light">
#                 Feb 13
#             </time>
# </div>
# <div class="msg-conversation-card__row">
# <div class="msg-overlay-list-bubble__message-snippet-container">
# <!-- --> <p class="msg-overlay-list-bubble__message-snippet--v2 m0 t-black t-12 t-normal t-black--light">
# <span>
# <span class="msg-conversation-card__message-snippet-body">
#             You: Ok , I will first give you a small gist .
# This would be an unpaid internship but if you do well and our startup succeeds , you will get quite a decent pay .
# You day to day duties would include coming up with product and marketing ideas , promoting our app on social media and managing posters and videos as well as telecommunication to boost our userbase .
# It won't be limited to just this , you can participate in any other activity of the business and learn from it with us .
# Hope you now have a clear idea of your work and benefits .
# We would give you a recommendation and a certificate and if we get incubated in IIT M , you can also recieve a certificate from them .
# So if you are still interested and want to work with us , please share your number and we can have a conversation and you can get started 😁
#             </span>
# </span>
# </p>
# </div>
# <div class="msg-conversation-card__conversation-status align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item" role="button" tabindex="0">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card display-flex">
# <div class="msg-selectable-entity msg-selectable-entity--3">
# <div class="presence-entity presence-entity--size-3 msg-selectable-entity__entity">
# <img alt="Siddharth Pandey" class="presence-entity__image EntityPhoto-circle-3 lazy-image ember-view" id="ember208" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C5603AQGv_G_jXm4y4A/profile-displayphoto-shrink_100_100/0/1612201875988?e=1629936000&amp;v=beta&amp;t=IMK_Ua4TSWpe6YVqRd-m2mvKNnbVuLNjyNDbANLQHyI"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator presence-indicator--is-reachable presence-indicator--size-3">
# <span class="visually-hidden">
#       Status is reachable
#   </span>
# </div>
# </div>
# <div class="msg-selectable-entity__checkbox-container">
# <input class="ember-checkbox msg-selectable-entity__input simple-form ember-view" id="checkbox-msg-selectable-entity__checkbox-ember207" tabindex="-1" type="checkbox"/>
# <label aria-label="Select conversation" class="msg-selectable-entity__checkbox-label ml2" for="checkbox-msg-selectable-entity__checkbox-ember207">
# </label>
# <div class="msg-selectable-entity__checkbox-circle-container">
# <div class="msg-selectable-entity__checkbox-circle">
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden pl2">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               Siddharth Pandey
#                       </h4>
# <time class="msg-overlay-list-bubble-item__time-stamp t-12 t-normal t-black--light">
#                 Jan 20
#             </time>
# </div>
# <div class="msg-conversation-card__row">
# <div class="msg-overlay-list-bubble__message-snippet-container">
# <!-- --> <p class="msg-overlay-list-bubble__message-snippet--v2 m0 t-black t-12 t-normal t-black--light">
# <span>
# <span class="msg-conversation-card__message-snippet-body">
#             You: Both
#             </span>
# </span>
# </p>
# </div>
# <div class="msg-conversation-card__conversation-status align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="msg-conversation-listitem__link msg-overlay-list-bubble__convo-item" role="button" tabindex="0">
# <div class="msg-conversation-card msg-overlay-list-bubble__convo-card display-flex">
# <div class="msg-selectable-entity msg-selectable-entity--3">
# <div class="presence-entity presence-entity--size-3 msg-selectable-entity__entity">
# <img alt="NIKHIL AGARWAL" class="presence-entity__image EntityPhoto-circle-3 lazy-image ember-view" id="ember211" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C4E35AQGZaCXzxl27Ow/profile-framedphoto-shrink_100_100/0/1611408697484?e=1624820400&amp;v=beta&amp;t=D7bu288nGLYvXyNU3oqNdzfk6yoM7WTPc0Oc5MzGq8k"/>
# <div class="presence-entity__indicator presence-entity__indicator--size-3 presence-indicator presence-indicator--is-reachable presence-indicator--size-3">
# <span class="visually-hidden">
#       Status is reachable
#   </span>
# </div>
# </div>
# <div class="msg-selectable-entity__checkbox-container">
# <input class="ember-checkbox msg-selectable-entity__input simple-form ember-view" id="checkbox-msg-selectable-entity__checkbox-ember210" tabindex="-1" type="checkbox"/>
# <label aria-label="Select conversation" class="msg-selectable-entity__checkbox-label ml2" for="checkbox-msg-selectable-entity__checkbox-ember210">
# </label>
# <div class="msg-selectable-entity__checkbox-circle-container">
# <div class="msg-selectable-entity__checkbox-circle">
# </div>
# </div>
# </div>
# </div>
# <div class="msg-overlay-list-bubble__convo-card-content overflow-hidden pl2">
# <div class="msg-overlay-list-bubble__convo-card-content-wrapper fl">
# <div class="msg-conversation-card__row">
# <h4 class="msg-conversation-listitem__participant-names msg-conversation-card__participant-names truncate t-14 t-black t-normal">
#               NIKHIL AGARWAL
#                       </h4>
# <time class="msg-overlay-list-bubble-item__time-stamp t-12 t-normal t-black--light">
#                 Jan 16
#             </time>
# </div>
# <div class="msg-conversation-card__row">
# <div class="msg-overlay-list-bubble__message-snippet-container">
# <!-- --> <p class="msg-overlay-list-bubble__message-snippet--v2 m0 t-black t-12 t-normal t-black--light">
# <span>
# <span class="msg-conversation-card__message-snippet-body">
#             You: Sure
#             </span>
# </span>
# </p>
# </div>
# <div class="msg-conversation-card__conversation-status align-items-center flex-grow-1">
# <!-- --><!-- --> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- --> <div class="msg-overlay-list-bubble__loader hidden">
# <div class="artdeco-loader artdeco-loader--small ember-view" id="ember213"><!-- -->
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# <span class="artdeco-loader__bars"></span>
# </div>
# </div>
# <div>
# </div>
# </div>
# </section>
# <!-- -->
# <!-- --><!-- --></div>
# <!-- -->
# <!-- -->
# <div id="msg-overlay__emoji-hoverable-outlet"></div>
# </aside>
# <img class="third-party-tracking-pixel hidden ember-view" id="ember115" src="https://px.ads.linkedin.com/collect/?pid=6883&amp;fmt=gif&amp;_t=1624730412487"/>
# </div>
# <div id="li-modal-container"></div>
# <div id="artdeco-hoverable-outlet"> <div aria-hidden="true" class="artdeco-hoverable-content pv-profile-info-section__hoverable-content artdeco-hoverable-content--inverse-theme artdeco-hoverable-content--default-spacing artdeco-hoverable-content--undefined-placement" id="artdeco-hoverable-artdeco-gen-42" role="tooltip" tabindex="-1">
# <div class="artdeco-hoverable-content__shell">
# <div class="artdeco-hoverable-content__content">
# <p>
#         See and edit how you look to people who are not signed in, and find you through search engines (ex: Google, Bing).
#       </p>
# </div>
# <!-- --> </div>
# <div aria-hidden="true" class="artdeco-hoverable-content__arrow"></div>
# </div>
# <div aria-hidden="true" class="artdeco-hoverable-content pv-profile-info-section__hoverable-content artdeco-hoverable-content--inverse-theme artdeco-hoverable-content--default-spacing artdeco-hoverable-content--undefined-placement" id="artdeco-hoverable-artdeco-gen-43" role="tooltip" tabindex="-1">
# <div class="artdeco-hoverable-content__shell">
# <div class="artdeco-hoverable-content__content">
# <p>
#         Creating a profile in another language makes it easier for local business contacts and recruiters to find you on LinkedIn.
#       </p>
# </div>
# <!-- --> </div>
# <div aria-hidden="true" class="artdeco-hoverable-content__arrow"></div>
# </div>
# </div>
# <div class="entity-hovercard-container hidden ember-view" id="ember10"><div class="entity-hovercard p4" role="tooltip" tabindex="-1">
# <section class="entity-hovercard__loading-state">
#       Loading…
#     </section>
# </div></div>
# <!-- -->
# <!-- -->
# <div class="type-ahead type-ahead-wormhole" id="type-ahead-wormhole">
# </div>
# <div class="toast-wormhole" id="toast-wormhole">
# </div>
# <iframe sandbox="allow-scripts" src="//radar.cedexis.com/1/11326/radar.html" style="display:none;" title="cedex beacon iframe">
# </iframe>
# <div><!-- --></div>
# <code id="datalet-bpr-guid-2672460" style="display: none">
#   {"request":"/voyager/api/identity/dash/profiles?q\u003DmemberIdentity\u0026memberIdentity\u003Dsanchit-gupta-361581189\u0026decorationId\u003Dcom.linkedin.voyager.dash.deco.identity.profile.FullProfileWithEntities-84","status":200,"body":"bpr-guid-2672460","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-2672460" src="..." style="display: none"/><code id="bpr-guid-2672461" style="display: none">
#   {"data":{"entityUrn":"urn:li:collectionResponse:gAsxValQ0/x9X+j1Ifco5pS056s2cFhgLem0hFl9EQI=","paging":{"count":10,"start":0,"links":[]},"*elements":["urn:li:fsd_profile:ACoAACxmnLkBWHVzr1Cem5z2R87rSJ5ChjrcBGE"],"$type":"com.linkedin.restli.common.CollectionResponse"},"meta":{"microSchema":{"version":"2","types":{"com.linkedin.voyager.dash.deco.common.video.AdaptiveStream":{"fields":{"initialBitRate":{"type":"int"},"protocol":{"type":"string"},"mediaType":{"type":"string"},"masterPlaylists":{"type":{"array":"com.linkedin.voyager.dash.deco.common.video.StreamingLocation"}}},"baseType":"com.linkedin.videocontent.AdaptiveStream"},"com.linkedin.voyager.dash.deco.common.text.TextViewModelV2":{"fields":{"textDirection":{"type":"string"},"text":{"type":"string"},"attributesV2":{"type":{"array":"com.linkedin.voyager.dash.deco.common.text.TextAttributeV2"}},"accessibilityTextAttributesV2":{"type":{"array":"com.linkedin.voyager.dash.deco.common.text.TextAttributeV2"}},"accessibilityText":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.common.text.TextViewModel"},"com.linkedin.deco.recipe.anonymous.Anon1529112441":{"fields":{"originalImageUrl":{"type":"string"},"originalHeight":{"type":"int"},"url":{"type":"string"},"originalWidth":{"type":"int"}},"baseType":"com.linkedin.voyager.dash.common.ImageUrl"},"com.linkedin.deco.recipe.anonymous.Anon909968925":{"fields":{"icon":{"type":"com.linkedin.voyager.dash.deco.common.image.ImageViewModel"},"composeNavigationContext":{"type":"com.linkedin.deco.recipe.anonymous.Anon1042380873"},"displayText":{"type":"com.linkedin.voyager.dash.deco.common.text.TextViewModelV2"},"textStartIcon":{"type":"com.linkedin.voyager.dash.deco.common.image.ImageViewModel"},"composeOptionType":{"type":"string"},"entityUrn":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.messaging.compose.ComposeOption"},"com.linkedin.voyager.dash.deco.common.video.StreamingLocation":{"fields":{"url":{"type":"string"},"expiresAt":{"type":"long"}},"baseType":"com.linkedin.videocontent.StreamingLocation"},"com.linkedin.voyager.dash.deco.relationships.MemberRelationshipV2":{"fields":{"memberRelationshipData":{"type":{"union":{"noInvitation":"com.linkedin.voyager.dash.deco.relationships.NoInvitation","invitation":"com.linkedin.voyager.dash.deco.relationships.Invitation","connection":"com.linkedin.voyager.dash.deco.relationships.Connection"}}},"entityUrn":{"type":"string"},"memberRelationshipUnion":{"type":{"union":{"self":"com.linkedin.restli.common.EmptyRecord","connection":"com.linkedin.voyager.dash.deco.relationships.Connection","noConnection":"com.linkedin.voyager.dash.deco.relationships.NoConnection"}}}},"baseType":"com.linkedin.voyager.dash.relationships.MemberRelationship"},"com.linkedin.deco.recipe.anonymous.Anon1976702492":{"fields":{"iweWarned":{"type":"boolean"},"entityUrn":{"type":"string"}},"baseType":"com.linkedin.voyager.dash.identity.profile.Profile"},"com.linkedin.voyager.dash.deco.common.video.VideoPlayMetadata":{"fields":{"thumbnail":{"type":"com.linkedin.voyager.dash.deco.common.VectorImageOnlyRootUrl"},"progressiveStreams":{"type":{"array":"com.linkedin.voyager.dash.deco.common.video.ProgressiveDownloadMetadata"}},"liveStreamCreatedAt":{"type":"long"},"transcripts":{"type":{"array":"com.linkedin.voyager.dash.deco.common.video.Transcript"}},"aspectRatio":{"type":"float"},"media":{"type":"string"},"adaptiveStreams":{"type":{"array":"com.linkedin.voyager.dash.deco.common.video.AdaptiveStream"}},"liveStreamEndedAt":{"type":"long"},"duration":{"type":"long"},"provider":{"type":"string"},"entityUrn":{"type":"string"},"thumbnails":{"type":{"array":"com.linkedin.voyager.dash.deco.common.video.Thumbnail"}},"trackingId":{"type":"string"}},"baseType":"com.linkedin.videocontent.VideoPlayMetadata"},"com.linkedin.voyager.dash.deco.relationships.ProfileWithEmailRequired":{"fields":{"memorialized":{"type":"boolean"},"lastName":{"type":"string"},"firstName":{"type":"string"},"tempStatus":{"type":"string"},"entityUrn": ...
# </code>
# <code id="datalet-bpr-guid-2672461" style="display: none">
#   {"request":"/voyager/api/identity/dash/profiles?q\u003DmemberIdentity\u0026memberIdentity\u003Dsanchit-gupta-361581189\u0026decorationId\u003Dcom.linkedin.voyager.dash.deco.identity.profile.TopCardSecondaryData-28","status":200,"body":"bpr-guid-2672461","method":"GET"}
# </code>
# <img class="datalet-bpr-guid-2672461" src="..." style="display: none"/><script id="fastboot-body-start" type="x/boundary"></script><script id="fastboot-body-end" type="x/boundary"></script><code id="clientPageInstance" style="display: none">
#   urn:li:page:d_flagship3_profile_view_base;JHrYyrM0Re2s/AxbjWkYlw==
# </code>
# <img class="terminatorlet" src="..." style="display: none"/>
# <div aria-live="polite" class="visually-hidden" id="a11y-notification" role="region"></div>
# </body></html>

# %%
name_div = soup.find('h1',{'class' : 'text-heading-xlarge'})
print(name_div)
# Out:
# <h1 class="text-heading-xlarge inline t-24 v-align-middle break-words">Sanchit Gupta</h1>

# %%
name_loc = name_div.get_text()
name = name_loc

# %%
connections_div = soup.find('span' , {'class' : 't-bold'})
connections = connections_div.get_text()
print(connections_div.get_text())
# Out:
# 350

# %%
about_div = soup.find_all('div', {'class' : 'mt4'})
# currentCompany = about_div[0].get_text()
about = about_div[0].get_text()
print(about)
# Out:
#     I am currently doing my BTech. Degree in Computer Science and Engineering from IIT Madras.I have worked on various skills and are improving them time to time.I am working on some startup ideas and some business models in which I hope to excel.I have a quite good management skill to manage anything and everything.I am a a former content developer at toppr and at startup - Melvano .I am currently working with startup - Relnto.Interested in Game development , I have already developed some games in Unity
#
#
# …
#
#           see more

# %%
# exp_section = soup.find('section', attrs = {'id': 'experience-section'})
# exp_section = exp_section.find('ul')
# div_tag = exp_section.find_all('div')
# print(div_tag[1])
exp_section = soup.find_all('li', attrs = {'class' : 'pv-entity__position-group-pager'})
experience = []
for exp in exp_section :
    experience.append(exp.find('p' , attrs = {'class' : 'pv-entity__secondary-title'}).get_text())
print(exp_section)
# Out:
# [<li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember268"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1686834438"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/company/sign-talk/" id="ember270"> <div class="pv-entity__logo company-logo">
# <img alt="SignTalk" class="pv-entity__logo-img EntityPhoto-square-5 lazy-image ember-view" id="ember272" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C510BAQHOBOV050hrJw/company-logo_100_100/0/1587125300317?e=1632960000&amp;v=beta&amp;t=YzuLMHfmiAU-HbFdLW0wpRh3qvkea7sJP2yufNII4mU"/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">Web Developer</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">
#       SignTalk
#         <span class="pv-entity__secondary-title separator">Internship</span>
# </p>
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Aug 2020 – May 2021</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">10 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Mumbai</span>
# </h4>
# <!-- -->
# </div>
# </a>
# <!-- --> </div>
# <div class="pv-entity__actions">
# <a class="pv-profile-section__edit-action pv-profile-section__hoverable-action artdeco-button artdeco-button--tertiary artdeco-button--circle artdeco-button--muted ember-view" data-control-name="edit_position" href="/in/sanchit-gupta-361581189/edit/position/1686834438/" id="ember274"> <li-icon aria-label="Edit position Web Developer" role="img" type="pencil-icon"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M21.13 2.86a3 3 0 00-4.17 0l-13 13L2 22l6.19-2L21.13 7a3 3 0 000-4.16zM6.77 18.57l-1.35-1.34L16.64 6 18 7.35z"></path>
# </svg></li-icon>
# </a><!-- --> </div>
# </div>
# </section>
# </li>, <li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember275"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1709945805"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="full-width ember-view" data-control-name="background_details_company" href="/company/newzera/" id="ember277"> <div class="pv-entity__logo company-logo">
# <img alt="Newzera" class="pv-entity__logo-img EntityPhoto-square-5 lazy-image ember-view" id="ember279" loading="lazy" src="https://media-exp1.licdn.com/dms/image/C4E0BAQFGXwLRM9eDUQ/company-logo_100_100/0/1621062728553?e=1632960000&amp;v=beta&amp;t=XyffxT1CVo2118hVR1oxbylt8rxv8xr9kZOBW63S-r0"/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">Software Developer Internship</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">
#       Newzera
#         <span class="pv-entity__secondary-title separator">Internship</span>
# </p>
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>Dec 2020 – Feb 2021</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">3 mos</span>
# </h4>
# </div>
# <!-- -->
# <!-- -->
# </div>
# </a>
# <!-- --> </div>
# <div class="pv-entity__actions">
# <a class="pv-profile-section__edit-action pv-profile-section__hoverable-action artdeco-button artdeco-button--tertiary artdeco-button--circle artdeco-button--muted ember-view" data-control-name="edit_position" href="/in/sanchit-gupta-361581189/edit/position/1709945805/" id="ember281"> <li-icon aria-label="Edit position Software Developer Internship" role="img" type="pencil-icon"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M21.13 2.86a3 3 0 00-4.17 0l-13 13L2 22l6.19-2L21.13 7a3 3 0 000-4.16zM6.77 18.57l-1.35-1.34L16.64 6 18 7.35z"></path>
# </svg></li-icon>
# </a><!-- --> </div>
# </div>
# </section>
# </li>, <li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember282"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1641811597"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view full-width" href="/search/results/all/?keywords=" id="ember284">
# <div class="pv-entity__logo company-logo">
# <img alt="" class="pv-entity__logo-img EntityPhoto-square-5 lazy-image ghost-freelance-experience ember-view" id="ember286" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">Mobile Application Developer</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">
#       Self-employed
#   </p>
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>May 2020 – Dec 2020</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">8 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Mumbai, Maharashtra, India</span>
# </h4>
# <!-- -->
# </div>
# </a>
# <!-- --> </div>
# <div class="pv-entity__actions">
# <a class="pv-profile-section__edit-action pv-profile-section__hoverable-action artdeco-button artdeco-button--tertiary artdeco-button--circle artdeco-button--muted ember-view" data-control-name="edit_position" href="/in/sanchit-gupta-361581189/edit/position/1641811597/" id="ember288"> <li-icon aria-label="Edit position Mobile Application Developer" role="img" type="pencil-icon"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M21.13 2.86a3 3 0 00-4.17 0l-13 13L2 22l6.19-2L21.13 7a3 3 0 000-4.16zM6.77 18.57l-1.35-1.34L16.64 6 18 7.35z"></path>
# </svg></li-icon>
# </a><!-- --> </div>
# </div>
# </section>
# </li>, <li class="pv-entity__position-group-pager pv-profile-section__list-item ember-view" id="ember289"> <section class="pv-profile-section__card-item-v2 pv-profile-section pv-position-entity ember-view" id="1641815049"> <div class="display-flex justify-space-between full-width">
# <div class="display-flex flex-column full-width">
# <a class="ember-view full-width" href="/search/results/all/?keywords=" id="ember291">
# <div class="pv-entity__logo company-logo">
# <img alt="" class="pv-entity__logo-img EntityPhoto-square-5 lazy-image ghost-freelance-experience ember-view" id="ember293" loading="lazy" src="..."/>
# </div>
# <div class="pv-entity__summary-info pv-entity__summary-info--background-section">
# <h3 class="t-16 t-black t-bold">Startup Engineer</h3>
# <p class="visually-hidden">Company Name</p>
# <p class="pv-entity__secondary-title t-14 t-black t-normal">
#       Self-employed
#   </p>
# <div class="display-flex">
# <h4 class="pv-entity__date-range t-14 t-black--light t-normal">
# <span class="visually-hidden">Dates Employed</span>
# <span>May 2020 – Dec 2020</span>
# </h4>
# <h4 class="t-14 t-black--light t-normal">
# <span class="visually-hidden">Employment Duration</span>
# <span class="pv-entity__bullet-item-v2">8 mos</span>
# </h4>
# </div>
# <h4 class="pv-entity__location t-14 t-black--light t-normal block">
# <span class="visually-hidden">Location</span>
# <span>Mumbai, Maharashtra, India</span>
# </h4>
# <!-- -->
# </div>
# </a>
# <!-- --> </div>
# <div class="pv-entity__actions">
# <a class="pv-profile-section__edit-action pv-profile-section__hoverable-action artdeco-button artdeco-button--tertiary artdeco-button--circle artdeco-button--muted ember-view" data-control-name="edit_position" href="/in/sanchit-gupta-361581189/edit/position/1641815049/" id="ember295"> <li-icon aria-label="Edit position Startup Engineer" role="img" type="pencil-icon"><svg class="mercado-match" data-supported-dps="24x24" fill="currentColor" focusable="false" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M21.13 2.86a3 3 0 00-4.17 0l-13 13L2 22l6.19-2L21.13 7a3 3 0 000-4.16zM6.77 18.57l-1.35-1.34L16.64 6 18 7.35z"></path>
# </svg></li-icon>
# </a><!-- --> </div>
# </div>
# </section>
# </li>]

# %%
edu_section = soup.find_all('li', attrs = {'class' : 'pv-education-entity'})
education = []
for edu in edu_section :
    education.append(edu.find('h3' , attrs = {'class' : 'pv-entity__school-name'}).get_text())
print(education)
# Out:
# []

# %%
profile = {"name" : name , "connections":connections , "about" : about , "experience" : experience , "education" : education}

# %%
for pro in profile :
    print(pro + " " + str(profile[pro]))
# Out:
# name Sanchit Gupta
# connections 350
# about
#
#     I am currently doing my BTech. Degree in Computer Science and Engineering from IIT Madras.I have worked on various skills and are improving them time to time.I am working on some startup ideas and some business models in which I hope to excel.I have a quite good management skill to manage anything and everything.I am a a former content developer at toppr and at startup - Melvano .I am currently working with startup - Relnto.Interested in Game development , I have already developed some games in Unity
#
#
# …
#
#           see more
#
#
#
# experience ['\n      SignTalk\n        Internship\n', '\n      Newzera\n        Internship\n', '\n      Self-employed\n  ', '\n      Self-employed\n  ']
# education []

# %%
# time.sleep(10)
browser.execute_script("window.scrollTo(0,0)")
time.sleep(5)

browser.find_element_by_class_name("link-without-visited-state").click()
# soup.find('a',attrs = {'class' : 'link-without-visited-state'})
# print(a)

# %%
time.sleep(5)
src = browser.page_source
soup = BeautifulSoup(src)

# %%
contact_info = soup.find_all('a', attrs = {'class' : 'pv-contact-info__contact-link'})
contact = []
for i in contact_info :
    contact.append(i.get_text())
print(contact)
# Out:
# ['\n        linkedin.com/in/sanchit-gupta-361581189\n      ', '\n          sanchitgupta456@gmail.com\n        ']

# %%
try :
    phone_number = soup.find_all('li',attrs ={'class':'pv-contact-info__ci-container'})
    phone_number = phone_number[1].find('span',attrs={'class' : 't-14'})
    phone_number = phone_number.get_text()
    print(phone_number)
except :
    print("No Phone number")
# Out:
# No Phone number

# %%
browser.get(profileLink)
SCROLL_PAUSE_TIME = 5

last_height = browser.execute_script('return document.body.scrollHeight')

for i in range(5) :
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight/4)")
    time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
    
src = browser.page_source
soup = BeautifulSoup(src)

# %%
browser.find_element_by_class_name("pv-profile-section__card-action-bar").click()
time.sleep(5)

# %%
# browser.find_element_by_class_name("pv-recent-activity-detail__pill").click()

# %%
l=browser.find_elements_by_class_name("pv-recent-activity-detail__pill")
l[2].click()
time.sleep(5)
SCROLL_PAUSE_TIME = 5

last_height = browser.execute_script('return document.body.scrollHeight')

for i in range(5) :
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight/2)")
    time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
browser.execute_script("window.scrollTo(0,0)")

l=browser.find_elements_by_class_name("see-more")
for i in range(len(l)) :
    l[i].click()
time.sleep(5)
SCROLL_PAUSE_TIME = 5

last_height = browser.execute_script('return document.body.scrollHeight')

for i in range(5) :
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight/2)")
    time.sleep(SCROLL_PAUSE_TIME)
    
    new_height = browser.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
src = browser.page_source
soup = BeautifulSoup(src)

# %%
posts = []
for i in range(len(l)) :
    try :
        post_info = soup.find_all('span', attrs = {'class' : 'break-words'})
#     print(post_info[0].find('span').find('span').get_text())
        posts.append(post_info[i].find('span').find('span').get_text())
    except :
        print("waited")
print(posts)
# Out:
# ['#esummit2021 Please like share and comment to support us .', 'Upsilon, A startup by IIT Madras students.We are trying to solve the problem of generation and management of employment opportunities for the tutors affected due to COVID-19 outbreak and provide viable opportunities to students who want to develop specific new skills.Unique Selling Proposition of our idea is to promote local teaching and all the search results of our app are ranked based on the proximity and rating of the course/skill being taught.Team MembersSanchit GuptaVedant SabooSaurav KaleRahul ChaudharyE-Cell IIT Madras#esummit2021 #sustain_to_attain#break_ground #make_a_start #education #opportunities #employment #students #startup']
